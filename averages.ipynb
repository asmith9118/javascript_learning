// %% [markdown]
// ## Exercise 1:
//
// ### A teacher has finished grading their students' tests and needs your help to calculate the average score for the class.

// %%
function getAverage(scores) {
    let sum = 0; 
  
      for(const i of scores){
        sum += i; 
      }
      
      return sum/scores.length;
    }
  
  
  console.log(getAverage([92, 88, 12, 77, 57, 100, 67, 38, 97, 89]));
  console.log(getAverage([45, 87, 98, 100, 86, 94, 67, 88, 94, 95]));
// Out:
// 71.7
// 85.4

// %%
function getGrade(score) {
    if (score === 100) {
      return "A++";
    } else if (score >= 90) {
      return "A";
    } else if (score >= 80) {
      return "B";
    } else if (score >= 70) {
      return "C";
    } else if (score >= 60) {
      return "D";
    } else {
      return "F";
    }
  }
  
  function hasPassingGrade(score) {
    return getGrade(score) !== "F";
  }

// %%
    
function getAverage(scores) {
  let sum = 0; 

    for(const i of scores){
      sum += i; 
    }
    
    return sum/scores.length;
  }

function getGrade(score) {
  if (score === 100) {
    return "A++";
  } else if (score >= 90) {
    return "A";
  } else if (score >= 80) {
    return "B";
  } else if (score >= 70) {
    return "C";
  } else if (score >= 60) {
    return "D";
  } else {
    return "F";
  }
}

function hasPassingGrade(score) {
  return getGrade(score) !== "F";
}
    
    function getGrade(score) {
    if (score === 100) {
      return "A++";
    } else if (score >= 90) {
      return "A";
    } else if (score >= 80) {
      return "B";
    } else if (score >= 70) {
      return "C";
    } else if (score >= 60) {
      return "D";
    } else {
      return "F";
    }
  }
  
  function hasPassingGrade(score) {
    return getGrade(score) !== "F";
  }
  
  function studentMsg(totalScores, studentScore) {
    let grade = getGrade(studentScore);
    let avg = getAverage(totalScores);
    let failMsg = "Class average: " + avg + ". " + "Your grade: " + grade + ". " 
      + "You failed the course.";
    let passMsg = "Class average: " + avg + ". " + "Your grade: " + grade + ". " 
      + "You passed the course.";
  
    if (hasPassingGrade(studentScore)){
      return passMsg;
    } else {
      return failMsg;
    }
  }
  console.log(studentMsg([92, 88, 12, 77, 57, 100, 67, 38, 97, 89], 37));
  console.log( studentMsg([56, 23, 89, 42, 75, 11, 68, 34, 91, 19], 100));
// Out:
// Class average: 71.7. Your grade: F. You failed the course.
// Class average: 50.8. Your grade: A++. You passed the course.

// %% [markdown]
// # Documentation for Student Grade Management Program
//
// This program provides a set of functions to manage student grades, calculate averages, determine letter grades, check passing status, and generate student messages.
//
// ## Functions
//
// ### `getAverage(scores)`
// - **Description**: Calculates the average of an array of scores.
// - **Parameters**:
//   - `scores` (Array\<number>): An array of numerical scores.
// - **Returns**:
//   - `number`: The average of the scores.
// - **Notes**:
//   - If `scores` is empty, this function will return `NaN` due to division by zero.
// - **Example**:
//   ```javascript
//   getAverage([90, 80, 70]); // returns 80
//   ```
//
// ---
//
// ### `getGrade(score)`
// - **Description**: Determines the letter grade for a given numerical score.
// - **Parameters**:
//   - `score` (number): A numerical score (0-100).
// - **Returns**:
//   - `string`: The letter grade based on the following scale:
//     | Score Range | Grade |
//     |-------------|-------|
//     | 100         | A++   |
//     | 90-99       | A     |
//     | 80-89       | B     |
//     | 70-79       | C     |
//     | 60-69       | D     |
//     | <60         | F     |
// - **Example**:
//   ```javascript
//   getGrade(85); // returns "B"
//   ```
//
// ---
//
// ### `hasPassingGrade(score)`
// - **Description**: Checks if a score corresponds to a passing grade (not "F").
// - **Parameters**:
//   - `score` (number): A numerical score (0-100).
// - **Returns**:
//   - `boolean`: `true` if the grade is not "F", `false` otherwise.
// - **Example**:
//   ```javascript
//   hasPassingGrade(45); // returns false
//   ```
//
// ---
//
// ### `studentMsg(totalScores, studentScore)`
// - **Description**: Generates a message for a student indicating their grade, class average, and pass/fail status.
// - **Parameters**:
//   - `totalScores` (Array\<number>): An array of all student scores in the class.
//   - `studentScore` (number): The individual student's score.
// - **Returns**:
//   - `string`: A formatted message containing the class average, the student's grade, and pass/fail status.
// - **Example**:
//   ```javascript
//   studentMsg([92, 88, 77], 45);
//   // Returns: "Class average: 85.67. Your grade: F. You failed the course."
//   ```
//
// ---
//
// ## Example Usage
// ```javascript
// console.log(studentMsg([92, 88, 12, 77, 57, 100, 67, 38, 97, 89], 37));
// // Output: "Class average: 71.7. Your grade: F. You failed the course."
//
// console.log(studentMsg([56, 23, 89, 42, 75, 11, 68, 34, 91, 19], 100));
// // Output: "Class average: 50.8. Your grade: A++. You passed the course."
// ```
//
// ---
//
// ## Notes
// 1. **Error Handling**:
//    - `getAverage` does not handle empty arrays. Ensure the input array is non-empty.
//    - Scores above 100 are treated as "A" (since `score >= 90` evaluates to `true` for values like 105).
// 2. **Function Duplication**: The code provided has duplicate definitions of `getGrade` and `hasPassingGrade`. The latter definitions override the earlier ones, but they are functionally identical.

// %%
/**
 * Calculates the average of an array of scores.
 * @param {number[]} scores - Array of numerical scores (0-100)
 * @returns {number} Arithmetic mean of scores. Returns NaN for empty arrays.
 */
function getAverage(scores) {
    let sum = 0;
    for (const score of scores) {
      sum += score;
    }
    return sum / scores.length;
  }
  
  /**
   * Determines letter grade based on numerical score.
   * @param {number} score - Numerical score (0-100)
   * @returns {string} Letter grade (A++, A, B, C, D, or F)
   * @note Scores above 100 will return A (not A++)
   */
  function getGrade(score) {
    if (score === 100) {
      return "A++";
    } else if (score >= 90) {
      return "A";
    } else if (score >= 80) {
      return "B";
    } else if (score >= 70) {
      return "C";
    } else if (score >= 60) {
      return "D";
    } else {
      return "F";
    }
  }
  
  /**
   * Determines if a score represents a passing grade.
   * @param {number} score - Numerical score (0-100)
   * @returns {boolean} True if grade is D or better, false otherwise
   */
  function hasPassingGrade(score) {
    return getGrade(score) !== "F";
  }
  
  /**
   * Generates formatted student result message with class comparison.
   * @param {number[]} totalScores - All class scores for average calculation
   * @param {number} studentScore - Individual student's score
   * @returns {string} Formatted message with average, grade, and pass/fail status
   */
  function studentMsg(totalScores, studentScore) {
    const grade = getGrade(studentScore);
    const rawAverage = getAverage(totalScores);
    const formattedAverage = rawAverage.toFixed(1); // Format to 1 decimal place
    
    const statusMessage = hasPassingGrade(studentScore) 
      ? "You passed the course." 
      : "You failed the course.";
  
    return `Class average: ${formattedAverage}. Your grade: ${grade}. ${statusMessage}`;
  }
  
  // Example Usage
  console.log(studentMsg([92, 88, 12, 77, 57, 100, 67, 38, 97, 89], 37));
  console.log(studentMsg([56, 23, 89, 42, 75, 11, 68, 34, 91, 19], 100));
